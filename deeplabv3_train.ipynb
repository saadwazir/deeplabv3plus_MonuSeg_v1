# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline
from tqdm import tqdm
from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
#import tensorflow.compat.v1 as tf
#tf.disable_v2_behavior()


gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)



from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1 Physical GPUs, 1 Logical GPUs
# Using TensorFlow backend.

# %%
# Set some parameters
im_width = 256
im_height = 256

train_ti_ids = next(os.walk("C:\MonuSeg_Short/Training/TissueImages/"))[2] # list of names all images in the given path
#print("No. of images = ", len(train_ti_ids))

train_gt_ids = []

for i in range( len(train_ti_ids) ):
    my_str = train_ti_ids[i]
    train_gt_ids.append(my_str)

    
test_ti_ids = next(os.walk("C:\MonuSeg_Short/Test/TissueImages/"))[2] # list of names all images in the given path
#print("No. of images = ", len(train_ti_ids))

test_gt_ids = []

for i in range( len(test_ti_ids) ):
    my_str = test_ti_ids[i]
    test_gt_ids.append(my_str)


def con_img_array(ids, base_path):
    X = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)
    for i in (range(len(ids))):
        #print(ids[i])
        img = load_img( base_path + ids[i] , color_mode = "grayscale")
        x_img = img_to_array(img)
        x_img = resize(x_img, (im_height, im_width, 1), mode = 'constant', preserve_range = True)
        X[i] = x_img/255.0
    #print("=========================================")
    return X

def con_img_array_rgb(ids, base_path):
    X = np.zeros((len(ids), im_height, im_width, 3), dtype=np.float32)
    for i in (range(len(ids))):
        #print(ids[i])
        img = load_img( base_path + ids[i] , color_mode = "rgb")
        x_img = img_to_array(img)
        x_img = resize(x_img, (im_height, im_width, 3), mode = 'constant', preserve_range = True)
        X[i] = x_img/255.0
    #print("=========================================")
    return X


X_train = con_img_array_rgb(train_ti_ids, "C:\MonuSeg_Short/Training/TissueImages/")
y_train = con_img_array(train_gt_ids, "C:\MonuSeg_Short/Training/GroundTruth/")
X_test = con_img_array_rgb(test_ti_ids, "C:\MonuSeg_Short/Test/TissueImages/")
y_test = con_img_array(test_gt_ids, "C:\MonuSeg_Short/Test/GroundTruth/")

print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (1470, 256, 256, 3)
# (1470, 256, 256, 1)
# (686, 256, 256, 3)
# (686, 256, 256, 1)

# %%
from numpy import save
save('X_train_short.npy', X_train)
save('y_train_short.npy', y_train)
save('X_test_short.npy', X_test)
save('y_test_short.npy', y_test)

# %%
from numpy import load
# load array
X_train = load('X_train_short.npy')
y_train = load('y_train_short.npy')
X_test = load('X_test_short.npy')
y_test = load('y_test_short.npy')

print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)

# %%
from tensorflow.python.keras.models import Model
from tensorflow.python.keras import layers
from tensorflow.python.keras.layers import Input
from tensorflow.python.keras.layers import Lambda
from tensorflow.python.keras.layers import Activation
from tensorflow.python.keras.layers import Concatenate
from tensorflow.python.keras.layers import Add
from tensorflow.python.keras.layers import Dropout
from tensorflow.python.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Conv2D
from tensorflow.python.keras.layers import DepthwiseConv2D
from tensorflow.python.keras.layers import ZeroPadding2D
from tensorflow.python.keras.layers import GlobalAveragePooling2D
from tensorflow.python.keras.utils.layer_utils import get_source_inputs
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.applications.imagenet_utils import preprocess_input

WEIGHTS_PATH_X = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_MOBILE = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_X_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"
WEIGHTS_PATH_MOBILE_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"


def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):
    """ SepConv with BN between depthwise & pointwise. Optionally add activation after BN
        Implements right "same" padding for even kernel sizes
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & poinwise convs
            epsilon: epsilon to use in BN layer
    """

    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation(tf.nn.relu)(x)

    return x


def _conv2d_same(x, filters, prefix, stride=1, kernel_size=3, rate=1):
    """Implements right 'same' padding for even kernel sizes
        Without this there is a 1 pixel drift when stride = 2
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
    """
    if stride == 1:
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='same', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='valid', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)


def _xception_block(inputs, depth_list, prefix, skip_connection_type, stride,
                    rate=1, depth_activation=False, return_skip=False):
    """ Basic building block of modified Xception network
        Args:
            inputs: input tensor
            depth_list: number of filters in each SepConv layer. len(depth_list) == 3
            prefix: prefix before name
            skip_connection_type: one of {'conv','sum','none'}
            stride: stride at last depthwise conv
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & pointwise convs
            return_skip: flag to return additional tensor after 2 SepConvs for decoder
            """
    residual = inputs
    for i in range(3):
        residual = SepConv_BN(residual,
                              depth_list[i],
                              prefix + '_separable_conv{}'.format(i + 1),
                              stride=stride if i == 2 else 1,
                              rate=rate,
                              depth_activation=depth_activation)
        if i == 1:
            skip = residual
    if skip_connection_type == 'conv':
        shortcut = _conv2d_same(inputs, depth_list[-1], prefix + '_shortcut',
                                kernel_size=1,
                                stride=stride)
        shortcut = BatchNormalization(name=prefix + '_shortcut_BN')(shortcut)
        outputs = layers.add([residual, shortcut])
    elif skip_connection_type == 'sum':
        outputs = layers.add([residual, inputs])
    elif skip_connection_type == 'none':
        outputs = residual
    if return_skip:
        return outputs, skip
    else:
        return outputs


def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id, skip_connection, rate=1):
    in_channels = inputs.shape[-1].value  # inputs._keras_shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs
    prefix = 'expanded_conv_{}_'.format(block_id)
    if block_id:
        # Expand

        x = Conv2D(expansion * in_channels, kernel_size=1, padding='same',
                   use_bias=False, activation=None,
                   name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                               name=prefix + 'expand_BN')(x)
        x = Activation(tf.nn.relu6, name=prefix + 'expand_relu')(x)
    else:
        prefix = 'expanded_conv_'
    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None,
                        use_bias=False, padding='same', dilation_rate=(rate, rate),
                        name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'depthwise_BN')(x)

    x = Activation(tf.nn.relu6, name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters,
               kernel_size=1, padding='same', use_bias=False, activation=None,
               name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'project_BN')(x)

    if skip_connection:
        return Add(name=prefix + 'add')([inputs, x])

    # if in_channels == pointwise_filters and stride == 1:
    #    return Add(name='res_connect_' + str(block_id))([inputs, x])

    return x


def Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(512, 512, 3), classes=21, backbone='mobilenetv2',
              OS=16, alpha=1., activation=None):
    """ Instantiates the Deeplabv3+ architecture
    Optionally loads weights pre-trained
    on PASCAL VOC or Cityscapes. This model is available for TensorFlow only.
    # Arguments
        weights: one of 'pascal_voc' (pre-trained on pascal voc),
            'cityscapes' (pre-trained on cityscape) or None (random initialization)
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: shape of input image. format HxWxC
            PASCAL VOC model was trained on (512,512,3) images. None is allowed as shape/width
        classes: number of desired classes. PASCAL VOC has 21 classes, Cityscapes has 19 classes.
            If number of classes not aligned with the weights used, last layer is initialized randomly
        backbone: backbone to use. one of {'xception','mobilenetv2'}
        activation: optional activation to add to the top of the network.
            One of 'softmax', 'sigmoid' or None
        OS: determines input_shape/feature_extractor_output ratio. One of {8,16}.
            Used only for xception backbone.
        alpha: controls the width of the MobileNetV2 network. This is known as the
            width multiplier in the MobileNetV2 paper.
                - If `alpha` < 1.0, proportionally decreases the number
                    of filters in each layer.
                - If `alpha` > 1.0, proportionally increases the number
                    of filters in each layer.
                - If `alpha` = 1, default number of filters from the paper
                    are used at each layer.
            Used only for mobilenetv2 backbone. Pretrained is only available for alpha=1.
    # Returns
        A Keras model instance.
    # Raises
        RuntimeError: If attempting to run this model with a
            backend that does not support separable convolutions.
        ValueError: in case of invalid argument for `weights` or `backbone`
    """

    if not (weights in {'pascal_voc', 'cityscapes', None}):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization), `pascal_voc`, or `cityscapes` '
                         '(pre-trained on PASCAL VOC)')

    if not (backbone in {'xception', 'mobilenetv2'}):
        raise ValueError('The `backbone` argument should be either '
                         '`xception`  or `mobilenetv2` ')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        img_input = input_tensor

    if backbone == 'xception':
        if OS == 8:
            entry_block3_stride = 1
            middle_block_rate = 2  # ! Not mentioned in paper, but required
            exit_block_rates = (2, 4)
            atrous_rates = (12, 24, 36)
        else:
            entry_block3_stride = 2
            middle_block_rate = 1
            exit_block_rates = (1, 2)
            atrous_rates = (6, 12, 18)

        x = Conv2D(32, (3, 3), strides=(2, 2),
                   name='entry_flow_conv1_1', use_bias=False, padding='same')(img_input)
        x = BatchNormalization(name='entry_flow_conv1_1_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _conv2d_same(x, 64, 'entry_flow_conv1_2', kernel_size=3, stride=1)
        x = BatchNormalization(name='entry_flow_conv1_2_BN')(x)
        x = Activation(tf.nn.relu)(x)

        x = _xception_block(x, [128, 128, 128], 'entry_flow_block1',
                            skip_connection_type='conv', stride=2,
                            depth_activation=False)
        x, skip1 = _xception_block(x, [256, 256, 256], 'entry_flow_block2',
                                   skip_connection_type='conv', stride=2,
                                   depth_activation=False, return_skip=True)

        x = _xception_block(x, [728, 728, 728], 'entry_flow_block3',
                            skip_connection_type='conv', stride=entry_block3_stride,
                            depth_activation=False)
        for i in range(16):
            x = _xception_block(x, [728, 728, 728], 'middle_flow_unit_{}'.format(i + 1),
                                skip_connection_type='sum', stride=1, rate=middle_block_rate,
                                depth_activation=False)

        x = _xception_block(x, [728, 1024, 1024], 'exit_flow_block1',
                            skip_connection_type='conv', stride=1, rate=exit_block_rates[0],
                            depth_activation=False)
        x = _xception_block(x, [1536, 1536, 2048], 'exit_flow_block2',
                            skip_connection_type='none', stride=1, rate=exit_block_rates[1],
                            depth_activation=True)

    else:
        OS = 8
        first_block_filters = _make_divisible(32 * alpha, 8)
        x = Conv2D(first_block_filters,
                   kernel_size=3,
                   strides=(2, 2), padding='same',
                   use_bias=False, name='Conv')(img_input)
        x = BatchNormalization(
            epsilon=1e-3, momentum=0.999, name='Conv_BN')(x)
        x = Activation(tf.nn.relu6, name='Conv_Relu6')(x)

        x = _inverted_res_block(x, filters=16, alpha=alpha, stride=1,
                                expansion=1, block_id=0, skip_connection=False)

        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
                                expansion=6, block_id=1, skip_connection=False)
        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=1,
                                expansion=6, block_id=2, skip_connection=True)

        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=2,
                                expansion=6, block_id=3, skip_connection=False)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=4, skip_connection=True)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=5, skip_connection=True)

        # stride in block 6 changed from 2 -> 1, so we need to use rate = 2
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1,  # 1!
                                expansion=6, block_id=6, skip_connection=False)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=7, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=8, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=9, skip_connection=True)

        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=10, skip_connection=False)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=11, skip_connection=True)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=12, skip_connection=True)

        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=2,  # 1!
                                expansion=6, block_id=13, skip_connection=False)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=14, skip_connection=True)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=15, skip_connection=True)

        x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=16, skip_connection=False)

    # end of feature extractor

    # branching for Atrous Spatial Pyramid Pooling

    # Image Feature branch
    shape_before = tf.shape(x)
    b4 = GlobalAveragePooling2D()(x)
    # from (b_size, channels)->(b_size, 1, 1, channels)
    b4 = Lambda(lambda x: K.expand_dims(x, 1))(b4)
    b4 = Lambda(lambda x: K.expand_dims(x, 1))(b4)
    b4 = Conv2D(256, (1, 1), padding='same',
                use_bias=False, name='image_pooling')(b4)
    b4 = BatchNormalization(name='image_pooling_BN', epsilon=1e-5)(b4)
    b4 = Activation(tf.nn.relu)(b4)
    # upsample. have to use compat because of the option align_corners
    size_before = tf.keras.backend.int_shape(x)
    b4 = Lambda(lambda x: tf.compat.v1.image.resize(x, size_before[1:3],
                                                    method='bilinear', align_corners=True))(b4)
    # simple 1x1
    b0 = Conv2D(256, (1, 1), padding='same', use_bias=False, name='aspp0')(x)
    b0 = BatchNormalization(name='aspp0_BN', epsilon=1e-5)(b0)
    b0 = Activation(tf.nn.relu, name='aspp0_activation')(b0)

    # there are only 2 branches in mobilenetV2. not sure why
    if backbone == 'xception':
        # rate = 6 (12)
        b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
        b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
        b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
        x = Concatenate()([b4, b0, b1, b2, b3])
    else:
        x = Concatenate()([b4, b0])

    x = Conv2D(256, (1, 1), padding='same',
               use_bias=False, name='concat_projection')(x)
    x = BatchNormalization(name='concat_projection_BN', epsilon=1e-5)(x)
    x = Activation(tf.nn.relu)(x)
    x = Dropout(0.1)(x)
    # DeepLab v.3+ decoder

    if backbone == 'xception':
        # Feature projection
        # x4 (x2) block
        size_before2 = tf.keras.backend.int_shape(x)
        x = Lambda(lambda xx: tf.compat.v1.image.resize(xx,
                                                        skip1.shape[1:3],
                                                        method='bilinear', align_corners=True))(x)

        dec_skip1 = Conv2D(48, (1, 1), padding='same',
                           use_bias=False, name='feature_projection0')(skip1)
        dec_skip1 = BatchNormalization(
            name='feature_projection0_BN', epsilon=1e-5)(dec_skip1)
        dec_skip1 = Activation(tf.nn.relu)(dec_skip1)
        x = Concatenate()([x, dec_skip1])
        x = SepConv_BN(x, 256, 'decoder_conv0',
                       depth_activation=True, epsilon=1e-5)
        x = SepConv_BN(x, 256, 'decoder_conv1',
                       depth_activation=True, epsilon=1e-5)

    # you can use it with arbitary number of classes
    if (weights == 'pascal_voc' and classes == 21) or (weights == 'cityscapes' and classes == 19):
        last_layer_name = 'logits_semantic'
    else:
        last_layer_name = 'custom_logits_semantic'

    x = Conv2D(classes, (1, 1), padding='same', name=last_layer_name)(x)
    size_before3 = tf.keras.backend.int_shape(img_input)
    x = Lambda(lambda xx: tf.compat.v1.image.resize(xx,
                                                    size_before3[1:3],
                                                    method='bilinear', align_corners=True))(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    if activation in {'softmax', 'sigmoid'}:
        x = tf.keras.layers.Activation(activation)(x)

    model = Model(inputs, x, name='deeplabv3plus')

    # load weights

    if weights == 'pascal_voc':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_X,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_MOBILE,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    elif weights == 'cityscapes':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5',
                                    WEIGHTS_PATH_X_CS,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5',
                                    WEIGHTS_PATH_MOBILE_CS,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    return model

def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.
    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].
    # Returns
        Input array scaled to [-1.,1.]
    """
    return preprocess_input(x, mode='tf')

# %%
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=1):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
    """
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    return (2. * intersection + smooth) / (K.sum(K.square(y_true),-1) + K.sum(K.square(y_pred),-1) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def focal_loss(gamma=2., alpha=.25):
	def focal_loss_fixed(y_true, y_pred):
		pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
		pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
		return -K.mean(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1)) - K.mean((1 - alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0))
	return focal_loss_fixed

def binary_focal_loss_fixed(y_true, y_pred, alpha = .25, gamma=2.):
        """
        :param y_true: A tensor of the same shape as `y_pred`
        :param y_pred:  A tensor resulting from a sigmoid
        :return: Output tensor.
        """
        y_true=y_true[:,:,:,0]
        y_pred=y_pred[:,:,:,0]
        
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))

        epsilon = K.epsilon()
        # clip to prevent NaN's and Inf's
        pt_1 = K.clip(pt_1, epsilon, 1. - epsilon)
        pt_0 = K.clip(pt_0, epsilon, 1. - epsilon)

        return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1)) \
               -K.sum((1 - alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0))

def focal_dice(y_true, y_pred, alpha = .25, gamma=2.):
    return dice_coef_loss(y_true, y_pred) + binary_focal_loss_fixed(y_true, y_pred, alpha = .25, gamma=2.)
    


binary_crossentropy = "binary_crossentropy"
from keras import optimizers

RMS = optimizers.RMSprop()
sgd = optimizers.SGD(lr=0.01, clipnorm=1.)

model = Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(256, 256, 3), classes=2, backbone='mobilenetv2',
              OS=16, alpha=1., activation='sigmoid') 
model.compile(optimizer=tf.keras.optimizers.Adam(), loss = focal_dice, metrics=["accuracy", f1_m, precision_m, recall_m, dice_coef])
#model.summary()

callbacks = [
    EarlyStopping(patience=50,   verbose=1),
    ReduceLROnPlateau(factor=0.1,  patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-deeplabvplus.h5', monitor='val_loss',  save_best_only=True, save_weights_only=True, verbose=1)
]

results=model.fit(X_train, y_train, batch_size=16, epochs=100, callbacks=callbacks , validation_split=0.3 , verbose = 1)
# Out:
# Train on 1029 samples, validate on 441 samples
# Epoch 1/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 113920.0876 - acc: 0.7729 - f1_m: 0.2979 - precision_m: 0.5474 - recall_m: 0.3545 - dice_coef: 0.8822
# Epoch 00001: val_loss improved from inf to 154825.73696, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 205s 200ms/sample - loss: 113461.9839 - acc: 0.7734 - f1_m: 0.2992 - precision_m: 0.5529 - recall_m: 0.3528 - dice_coef: 0.8823 - val_loss: 154825.7370 - val_acc: 0.9998 - val_f1_m: 0.4401 - val_precision_m: 0.4047 - val_recall_m: 0.5010 - val_dice_coef: 0.8671
# Epoch 2/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 41795.0667 - acc: 0.8095 - f1_m: 0.5698 - precision_m: 0.8207 - recall_m: 0.4427 - dice_coef: 0.9510
# Epoch 00002: val_loss improved from 154825.73696 to 122805.77551, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 65s 63ms/sample - loss: 41662.6326 - acc: 0.8094 - f1_m: 0.5704 - precision_m: 0.8220 - recall_m: 0.4430 - dice_coef: 0.9511 - val_loss: 122805.7755 - val_acc: 0.4561 - val_f1_m: 0.5869 - val_precision_m: 0.4185 - val_recall_m: 1.0054 - val_dice_coef: 0.8610
# Epoch 3/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 36296.8590 - acc: 0.8217 - f1_m: 0.8275 - precision_m: 0.8639 - recall_m: 0.8058 - dice_coef: 0.9800
# Epoch 00003: val_loss did not improve from 122805.77551
# 1029/1029 [==============================] - 64s 62ms/sample - loss: 36178.7661 - acc: 0.8216 - f1_m: 0.8287 - precision_m: 0.8641 - recall_m: 0.8078 - dice_coef: 0.9801 - val_loss: 200117.5603 - val_acc: 0.5566 - val_f1_m: 0.7379 - val_precision_m: 0.4930 - val_recall_m: 1.4754 - val_dice_coef: 0.8950
# Epoch 4/100
# 1024/1029 [============================>.] - ETA: 0s - loss:
100
# 1024/1029 [============================>.] - ETA: 0s - loss: 25550.1849 - acc: 0.7731 - f1_m: 1.0655 - precision_m: 0.9079 - recall_m: 1.2939 - dice_coef: 1.0127
# Epoch 00016: val_loss improved from 82552.86208 to 78748.91665, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 25473.9461 - acc: 0.7730 - f1_m: 1.0646 - precision_m: 0.9077 - recall_m: 1.2918 - dice_coef: 1.0127 - val_loss: 78748.9166 - val_acc: 0.5026 - val_f1_m: 0.8546 - val_precision_m: 0.5751 - val_recall_m: 1.6699 - val_dice_coef: 0.9259
# Epoch 17/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 25580.4187 - acc: 0.7728 - f1_m: 1.0651 - precision_m: 0.9087 - recall_m: 1.2925 - dice_coef: 1.0130
# Epoch 00017: val_loss improved from 78748.91665 to 72408.70531, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 25497.5506 - acc: 0.7729 - f1_m: 1.0648 - precision_m: 0.9082 - recall_m: 1.2926 - dice_coef: 1.0129 - val_loss: 72408.7053 - val_acc: 0.5112 - val_f1_m: 0.8699 - val_precision_m: 0.5913 - val_recall_m: 1.6524 - val_dice_coef: 0.9331
# Epoch 18/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 25218.9933 - acc: 0.7708 - f1_m: 1.0712 - precision_m: 0.9099 - recall_m: 1.3058 - dice_coef: 1.0138
# Epoch 00018: val_loss improved from 72408.70531 to 70471.10557, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 25136.3022 - acc: 0.7708 - f1_m: 1.0710 - precision_m: 0.9095 - recall_m: 1.3061 - dice_coef: 1.0138 - val_loss: 70471.1056 - val_acc: 0.5206 - val_f1_m: 0.8762 - val_precision_m: 0.6007 - val_recall_m: 1.6280 - val_dice_coef: 0.9362
# Epoch 19/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 24926.7924 - acc: 0.7720 - f1_m: 1.0728 - precision_m: 0.9117 - recall_m: 1.3072 - dice_coef: 1.0144
# Epoch 00019: val_loss improved from 70471.10557 to 62804.36129, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 24852.5279 - acc: 0.7721 - f1_m: 1.0721 - precision_m: 0.9109 - recall_m: 1.3066 - dice_coef: 1.0144 - val_loss: 62804.3613 - val_acc: 0.5496 - val_f1_m: 0.8939 - val_precision_m: 0.6221 - val_recall_m: 1.5933 - val_dice_coef: 0.9455
# Epoch 20/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 24666.6401 - acc: 0.7727 - f1_m: 1.0762 - precision_m: 0.9133 - recall_m: 1.3133 - dice_coef: 1.0151
# Epoch 00020: val_loss did not improve from 62804.36129
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 24600.1838 - acc: 0.7727 - f1_m: 1.0748 - precision_m: 0.9132 - recall_m: 1.3095 - dice_coef: 1.0150 - val_loss: 67650.4352 - val_acc: 0.5401 - val_f1_m: 0.8867 - val_precision_m: 0.6101 - val_recall_m: 1.6303 - val_dice_coef: 0.9415
# Epoch 21/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 24456.9233 - acc: 0.7708 - f1_m: 1.0799 - precision_m: 0.9132 - recall_m: 1.3246 - dice_coef: 1.0155
# Epoch 00021: val_loss did not improve from 62804.36129
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 24371.8274 - acc: 0.7709 - f1_m: 1.0803 - precision_m: 0.9127 - recall_m: 1.3272 - dice_coef: 1.0155 - val_loss: 63017.5448 - val_acc: 0.5655 - val_f1_m: 0.8982 - val_precision_m: 0.6272 - val_recall_m: 1.5864 - val_dice_coef: 0.9482
# Epoch 22/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 24209.6328 - acc: 0.7693 - f1_m: 1.0834 - precision_m: 0.9146 - recall_m: 1.3317 - dice_coef: 1.0163
# Epoch 00022: val_loss improved from 62804.36129 to 60200.31094, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 24131.6878 - acc: 0.7693 - f1_m: 1.0832 - precision_m: 0.9145 - recall_m: 1.3313 - dice_coef: 1.0163 - val_loss: 60200.3109 - val_acc: 0.5731 - val_f1_m: 0.9081 - val_precision_m: 0.6374 - val_recall_m: 1.5827 - val_dice_coef: 0.9510
# Epoch 23/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 24036.9245 - acc: 0.7693 - f1_m: 1.0856 - precision_m: 0.9169 - recall_m: 1.3338 - dice_coef: 1.0167
# Epoch 00023: val_loss improved from 60200.31094 to 56561.75291, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 23953.2234 - acc: 0.7694 - f1_m: 1.0857 - precision_m: 0.9164 - recall_m: 1.3354 - dice_coef: 1.0167 - val_loss: 56561.7529 - val_acc: 0.6092 - val_f1_m: 0.9217 - val_precision_m: 0.6589 - val_recall_m: 1.5420 - val_dice_coef: 0.9575
# Epoch 24/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 23788.3648 - acc: 0.7705 - f1_m: 1.0890 - precision_m: 0.9167 - recall_m: 1.3446 - dice_coef: 1.0172
# Epoch 00024: val_loss improved from 56561.75291 to 54882.40181, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 23711.5213 - acc: 0.7704 - f1_m: 1.0885 - precision_m: 0.9159 - recall_m: 1.3448 - dice_coef: 1.0172 - val_loss: 54882.4018 - val_acc: 0.6134 - val_f1_m: 0.9219 - val_precision_m: 0.6653 - val_recall_m: 1.5090 - val_dice_coef: 0.9602
# Epoch 25/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 23668.3010 - acc: 0.7688 - f1_m: 1.0904 - precision_m: 0.9174 - recall_m: 1.3484 - dice_coef: 1.0174
# Epoch 00025: val_loss improved from 54882.40181 to 49782.91725, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 23611.2220 - acc: 0.7686 - f1_m: 1.0889 - precision_m: 0.9170 - recall_m: 1.3449 - dice_coef: 1.0174 - val_loss: 49782.9172 - val_acc: 0.6453 - val_f1_m: 0.9368 - val_precision_m: 0.6928 - val_recall_m: 1.4506 - val_dice_coef: 0.9676
# Epoch 26/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 23272.8033 - acc: 0.7678 - f1_m: 1.0960 - precision_m: 0.9187 - recall_m: 1.3610 - dice_coef: 1.0185
# Epoch 00026: val_loss improved from 49782.91725 to 46839.22868, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 23192.6195 - acc: 0.7679 - f1_m: 1.0957 - precision_m: 0.9184 - recall_m: 1.3607 - dice_coef: 1.0185 - val_loss: 46839.2287 - val_acc: 0.6601 - val_f1_m: 0.9389 - val_precision_m: 0.7107 - val_recall_m: 1.3903 - val_dice_coef: 0.9714
# Epoch 27/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 23244.8678 - acc: 0.7671 - f1_m: 1.0959 - precision_m: 0.9202 - recall_m: 1.3586 - dice_coef: 1.0188
# Epoch 00027: val_loss did not improve from 46839.22868
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 23162.3362 - acc: 0.7672 - f1_m: 1.0960 - precision_m: 0.9189 - recall_m: 1.3626 - dice_coef: 1.0187 - val_loss: 48008.6814 - val_acc: 0.6551 - val_f1_m: 0.9406 - val_precision_m: 0.7000 - val_recall_m: 1.4403 - val_dice_coef: 0.9706
# Epoch 28/100
# 1024/1029 [============================>.] - ETA: 0s - loss:
100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20974.2437 - acc: 0.7663 - f1_m: 1.1240 - precision_m: 0.9311 - recall_m: 1.4205 - dice_coef: 1.0240
# Epoch 00046: val_loss improved from 41840.65574 to 41745.06197, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20906.7693 - acc: 0.7664 - f1_m: 1.1237 - precision_m: 0.9305 - recall_m: 1.4211 - dice_coef: 1.0240 - val_loss: 41745.0620 - val_acc: 0.7490 - val_f1_m: 0.9593 - val_precision_m: 0.7710 - val_recall_m: 1.2731 - val_dice_coef: 0.9858
# Epoch 47/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20903.2145 - acc: 0.7659 - f1_m: 1.1249 - precision_m: 0.9306 - recall_m: 1.4242 - dice_coef: 1.0241
# Epoch 00047: val_loss did not improve from 41745.06197
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20833.0696 - acc: 0.7659 - f1_m: 1.1249 - precision_m: 0.9306 - recall_m: 1.4241 - dice_coef: 1.0241 - val_loss: 41784.0644 - val_acc: 0.7500 - val_f1_m: 0.9589 - val_precision_m: 0.7703 - val_recall_m: 1.2722 - val_dice_coef: 0.9859
# Epoch 48/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20822.5357 - acc: 0.7648 - f1_m: 1.1262 - precision_m: 0.9309 - recall_m: 1.4279 - dice_coef: 1.0242
# Epoch 00048: val_loss improved from 41745.06197 to 41720.56547, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20751.4885 - acc: 0.7648 - f1_m: 1.1263 - precision_m: 0.9309 - recall_m: 1.4283 - dice_coef: 1.0243 - val_loss: 41720.5655 - val_acc: 0.7506 - val_f1_m: 0.9605 - val_precision_m: 0.7703 - val_recall_m: 1.2779 - val_dice_coef: 0.9859
# Epoch 49/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20789.0522 - acc: 0.7664 - f1_m: 1.1264 - precision_m: 0.9313 - recall_m: 1.4276 - dice_coef: 1.0244
# Epoch 00049: val_loss improved from 41720.56547 to 41411.92586, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20719.2007 - acc: 0.7662 - f1_m: 1.1265 - precision_m: 0.9307 - recall_m: 1.4295 - dice_coef: 1.0244 - val_loss: 41411.9259 - val_acc: 0.7552 - val_f1_m: 0.9585 - val_precision_m: 0.7744 - val_recall_m: 1.2600 - val_dice_coef: 0.9866
# Epoch 50/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20628.2393 - acc: 0.7656 - f1_m: 1.1285 - precision_m: 0.9312 - recall_m: 1.4343 - dice_coef: 1.0245
# Epoch 00050: val_loss did not improve from 41411.92586
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20570.5593 - acc: 0.7655 - f1_m: 1.1281 - precision_m: 0.9316 - recall_m: 1.4324 - dice_coef: 1.0246 - val_loss: 41561.1989 - val_acc: 0.7574 - val_f1_m: 0.9582 - val_precision_m: 0.7735 - val_recall_m: 1.2623 - val_dice_coef: 0.9866
# Epoch 51/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20586.5836 - acc: 0.7652 - f1_m: 1.1296 - precision_m: 0.9317 - recall_m: 1.4366 - dice_coef: 1.0247
# Epoch 00051: val_loss did not improve from 41411.92586
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20516.4447 - acc: 0.7652 - f1_m: 1.1299 - precision_m: 0.9319 - recall_m: 1.4371 - dice_coef: 1.0248 - val_loss: 41609.1720 - val_acc: 0.7547 - val_f1_m: 0.9587 - val_precision_m: 0.7704 - val_recall_m: 1.2714 - val_dice_coef: 0.9864
# Epoch 52/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20642.0570 - acc: 0.7641 - f1_m: 1.1278 - precision_m: 0.9321 - recall_m: 1.4303 - dice_coef: 1.0247
# Epoch 00052: val_loss did not improve from 41411.92586
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20577.9953 - acc: 0.7641 - f1_m: 1.1274 - precision_m: 0.9317 - recall_m: 1.4297 - dice_coef: 1.0247 - val_loss: 41586.1049 - val_acc: 0.7566 - val_f1_m: 0.9596 - val_precision_m: 0.7735 - val_recall_m: 1.2671 - val_dice_coef: 0.9868
# Epoch 53/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20590.3295 - acc: 0.7648 - f1_m: 1.1288 - precision_m: 0.9319 - recall_m: 1.4338 - dice_coef: 1.0248
# Epoch 00053: val_loss did not improve from 41411.92586
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20521.3463 - acc: 0.7649 - f1_m: 1.1286 - precision_m: 0.9319 - recall_m: 1.4331 - dice_coef: 1.0248 - val_loss: 41791.8031 - val_acc: 0.7551 - val_f1_m: 0.9610 - val_precision_m: 0.7727 - val_recall_m: 1.2730 - val_dice_coef: 0.9866
# Epoch 54/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20638.0469 - acc: 0.7649 - f1_m: 1.1286 - precision_m: 0.9311 - recall_m: 1.4356 - dice_coef: 1.0248
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00054: val_loss did not improve from 41411.92586
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20576.3475 - acc: 0.7649 - f1_m: 1.1282 - precision_m: 0.9304 - recall_m: 1.4358 - dice_coef: 1.0247 - val_loss: 41584.9191 - val_acc: 0.7598 - val_f1_m: 0.9594 - val_precision_m: 0.7771 - val_recall_m: 1.2563 - val_dice_coef: 0.9870
# Epoch 55/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20532.5105 - acc: 0.7641 - f1_m: 1.1295 - precision_m: 0.9317 - recall_m: 1.4367 - dice_coef: 1.0249
# Epoch 00055: val_loss did not improve from 41411.92586
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20470.9723 - acc: 0.7641 - f1_m: 1.1290 - precision_m: 0.9312 - recall_m: 1.4361 - dice_coef: 1.0248 - val_loss: 41637.9200 - val_acc: 0.7590 - val_f1_m: 0.9612 - val_precision_m: 0.7750 - val_recall_m: 1.2678 - val_dice_coef: 0.9870
# Epoch 56/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20552.4270 - acc: 0.7648 - f1_m: 1.1289 - precision_m: 0.9324 - recall_m: 1.4334 - dice_coef: 1.0249
# Epoch 00056: val_loss did not improve from 41411.92586
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20483.5050 - acc: 0.7648 - f1_m: 1.1289 - precision_m: 0.9325 - recall_m: 1.4329 - dice_coef: 1.0250 - val_loss: 41805.4411 - val_acc: 0.7623 - val_f1_m: 0.9594 - val_precision_m: 0.7773 - val_recall_m: 1.2553 - val_dice_coef: 0.9874
# Epoch 57/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20578.3439 - acc: 0.7644 - f1_m: 1.1297 - precision_m: 0.9309 - recall_m: 1.4393 - dice_coef: 1.0248
# Epoch 00057: val_loss improved from 41411.92586 to 40976.09843, saving model to model-deeplabvplus.h5
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20512.4775 - acc: 0.7644 - f1_m: 1.1298 - precision_m: 0.9313 - recall_m: 1.4387 - dice_coef: 1.0249 - val_loss: 40976.0984 - val_acc: 0.7697 - val_f1_m: 0.9558 - val_precision_m: 0.7824 - val_recall_m: 1.2300 - val_dice_coef: 0.9881
# Epoch 58/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20384.4109 - acc: 0.7648 - f1_m: 1.1308 - precision_m: 0.9334 - recall_m: 1.4366 - dice_coef: 1.0252
# Epoch 00058: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20324.2723 - acc: 0.7648 - f1_m: 1.1304 - precision_m: 0.9337 - recall_m: 1.4347 - dice_coef: 1.0253 - val_loss: 41839.2558 - val_acc: 0.7618 - val_f1_m: 0.9598 - val_precision_m: 0.7774 - val_recall_m: 1.2580 - val_dice_coef: 0.9874
# Epoch 59/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20432.9581 - acc: 0.7629 - f1_m: 1.1324 - precision_m: 0.9308 - recall_m: 1.4476 - dice_coef: 1.0252
# Epoch 00059: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20366.5723 - acc: 0.7629 - f1_m: 1.1321 - precision_m: 0.9304 - recall_m: 1.4477 - dice_coef: 1.0252 - val_loss: 41173.6404 - val_acc: 0.7723 - val_f1_m: 0.9548 - val_precision_m: 0.7849 - val_recall_m: 1.2209 - val_dice_coef: 0.9884
# Epoch 60/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20489.2491 - acc: 0.7642 - f1_m: 1.1305 - precision_m: 0.9318 - recall_m: 1.4407 - dice_coef: 1.0251
# Epoch 00060: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20419.0546 - acc: 0.7643 - f1_m: 1.1306 - precision_m: 0.9319 - recall_m: 1.4408 - dice_coef: 1.0251 - val_loss: 41267.4097 - val_acc: 0.7678 - val_f1_m: 0.9578 - val_precision_m: 0.7842 - val_recall_m: 1.2330 - val_dice_coef: 0.9880
# Epoch 61/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20528.5049 - acc: 0.7638 - f1_m: 1.1304 - precision_m: 0.9323 - recall_m: 1.4384 - dice_coef: 1.0251
# Epoch 00061: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20463.2129 - acc: 0.7638 - f1_m: 1.1298 - precision_m: 0.9312 - recall_m: 1.4395 - dice_coef: 1.0251 - val_loss: 41526.9875 - val_acc: 0.7674 - val_f1_m: 0.9584 - val_precision_m: 0.7822 - val_recall_m: 1.2399 - val_dice_coef: 0.9878
# Epoch 62/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20405.5427 - acc: 0.7646 - f1_m: 1.1304 - precision_m: 0.9335 - recall_m: 1.4357 - dice_coef: 1.0253
# Epoch 00062: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20338.0464 - acc: 0.7645 - f1_m: 1.1308 - precision_m: 0.9340 - recall_m: 1.4358 - dice_coef: 1.0254 - val_loss: 42040.8790 - val_acc: 0.7636 - val_f1_m: 0.9591 - val_precision_m: 0.7769 - val_recall_m: 1.2559 - val_dice_coef: 0.9874
# Epoch 63/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20218.4999 - acc: 0.7639 - f1_m: 1.1336 - precision_m: 0.9330 - recall_m: 1.4464 - dice_coef: 1.0256
# Epoch 00063: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20155.3611 - acc: 0.7638 - f1_m: 1.1331 - precision_m: 0.9325 - recall_m: 1.4463 - dice_coef: 1.0255 - val_loss: 41398.2406 - val_acc: 0.7697 - val_f1_m: 0.9580 - val_precision_m: 0.7822 - val_recall_m: 1.2369 - val_dice_coef: 0.9881
# Epoch 64/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20133.7993 - acc: 0.7629 - f1_m: 1.1345 - precision_m: 0.9336 - recall_m: 1.4476 - dice_coef: 1.0257
# Epoch 00064: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20066.2787 - acc: 0.7629 - f1_m: 1.1345 - precision_m: 0.9334 - recall_m: 1.4480 - dice_coef: 1.0257 - val_loss: 41485.7541 - val_acc: 0.7663 - val_f1_m: 0.9589 - val_precision_m: 0.7821 - val_recall_m: 1.2416 - val_dice_coef: 0.9878
# Epoch 65/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20147.2968 - acc: 0.7641 - f1_m: 1.1343 - precision_m: 0.9331 - recall_m: 1.4489 - dice_coef: 1.0257
# Epoch 00065: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20090.7860 - acc: 0.7641 - f1_m: 1.1335 - precision_m: 0.9332 - recall_m: 1.4461 - dice_coef: 1.0257 - val_loss: 41781.5280 - val_acc: 0.7638 - val_f1_m: 0.9601 - val_precision_m: 0.7777 - val_recall_m: 1.2578 - val_dice_coef: 0.9876
# Epoch 66/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20236.3777 - acc: 0.7650 - f1_m: 1.1335 - precision_m: 0.9336 - recall_m: 1.4450 - dice_coef: 1.0257
# Epoch 00066: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20169.1221 - acc: 0.7650 - f1_m: 1.1331 - precision_m: 0.9332 - recall_m: 1.4450 - dice_coef: 1.0257 - val_loss: 41342.1883 - val_acc: 0.7710 - val_f1_m: 0.9571 - val_precision_m: 0.7821 - val_recall_m: 1.2351 - val_dice_coef: 0.9883
# Epoch 67/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20096.4826 - acc: 0.7631 - f1_m: 1.1357 - precision_m: 0.9334 - recall_m: 1.4523 - dice_coef: 1.0259
# Epoch 00067: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20036.6816 - acc: 0.7630 - f1_m: 1.1350 - precision_m: 0.9336 - recall_m: 1.4498 - dice_coef: 1.0259 - val_loss: 41045.1512 - val_acc: 0.7764 - val_f1_m: 0.9545 - val_precision_m: 0.7905 - val_recall_m: 1.2059 - val_dice_coef: 0.9889
# Epoch 68/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 20206.8578 - acc: 0.7626 - f1_m: 1.1328 - precision_m: 0.9339 - recall_m: 1.4428 - dice_coef: 1.0258
# Epoch 00068: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 20136.3770 - acc: 0.7626 - f1_m: 1.1331 - precision_m: 0.9335 - recall_m: 1.4452 - dice_coef: 1.0258 - val_loss: 41920.7702 - val_acc: 0.7671 - val_f1_m: 0.9585 - val_precision_m: 0.7811 - val_recall_m: 1.2427 - val_dice_coef: 0.9882
# Epoch 69/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19956.6646 - acc: 0.7636 - f1_m: 1.1367 - precision_m: 0.9345 - recall_m: 1.4530 - dice_coef: 1.0263
# Epoch 00069: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19889.3444 - acc: 0.7636 - f1_m: 1.1364 - precision_m: 0.9335 - recall_m: 1.4549 - dice_coef: 1.0262 - val_loss: 42311.5332 - val_acc: 0.7644 - val_f1_m: 0.9591 - val_precision_m: 0.7781 - val_recall_m: 1.2528 - val_dice_coef: 0.9879
# Epoch 70/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19867.6682 - acc: 0.7625 - f1_m: 1.1374 - precision_m: 0.9341 - recall_m: 1.4556 - dice_coef: 1.0264
# Epoch 00070: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19809.2998 - acc: 0.7625 - f1_m: 1.1371 - precision_m: 0.9345 - recall_m: 1.4541 - dice_coef: 1.0264 - val_loss: 41971.9420 - val_acc: 0.7705 - val_f1_m: 0.9563 - val_precision_m: 0.7842 - val_recall_m: 1.2261 - val_dice_coef: 0.9885
# Epoch 71/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19797.7599 - acc: 0.7612 - f1_m: 1.1381 - precision_m: 0.9352 - recall_m: 1.4552 - dice_coef: 1.0267
# Epoch 00071: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19732.4652 - acc: 0.7613 - f1_m: 1.1378 - precision_m: 0.9344 - recall_m: 1.4563 - dice_coef: 1.0266 - val_loss: 41749.6129 - val_acc: 0.7734 - val_f1_m: 0.9570 - val_precision_m: 0.7874 - val_recall_m: 1.2216 - val_dice_coef: 0.9889
# Epoch 72/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19839.1120 - acc: 0.7634 - f1_m: 1.1390 - precision_m: 0.9341 - recall_m: 1.4615 - dice_coef: 1.0266
# Epoch 00072: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19775.2010 - acc: 0.7635 - f1_m: 1.1385 - precision_m: 0.9338 - recall_m: 1.4606 - dice_coef: 1.0266 - val_loss: 41577.1701 - val_acc: 0.7726 - val_f1_m: 0.9560 - val_precision_m: 0.7856 - val_recall_m: 1.2225 - val_dice_coef: 0.9889
# Epoch 73/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19950.7448 - acc: 0.7632 - f1_m: 1.1362 - precision_m: 0.9345 - recall_m: 1.4517 - dice_coef: 1.0264
# Epoch 00073: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19887.8932 - acc: 0.7632 - f1_m: 1.1357 - precision_m: 0.9346 - recall_m: 1.4500 - dice_coef: 1.0264 - val_loss: 41674.2440 - val_acc: 0.7724 - val_f1_m: 0.9547 - val_precision_m: 0.7858 - val_recall_m: 1.2180 - val_dice_coef: 0.9887
# Epoch 74/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19842.5752 - acc: 0.7628 - f1_m: 1.1380 - precision_m: 0.9347 - recall_m: 1.4567 - dice_coef: 1.0266
# Epoch 00074: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19774.9399 - acc: 0.7629 - f1_m: 1.1379 - precision_m: 0.9343 - recall_m: 1.4574 - dice_coef: 1.0266 - val_loss: 41927.9296 - val_acc: 0.7706 - val_f1_m: 0.9567 - val_precision_m: 0.7822 - val_recall_m: 1.2345 - val_dice_coef: 0.9882
# Epoch 75/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19796.3219 - acc: 0.7637 - f1_m: 1.1382 - precision_m: 0.9354 - recall_m: 1.4552 - dice_coef: 1.0266
# Epoch 00075: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19727.2061 - acc: 0.7638 - f1_m: 1.1386 - precision_m: 0.9355 - recall_m: 1.4564 - dice_coef: 1.0267 - val_loss: 41795.0526 - val_acc: 0.7742 - val_f1_m: 0.9531 - val_precision_m: 0.7854 - val_recall_m: 1.2135 - val_dice_coef: 0.9887
# Epoch 76/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19855.3641 - acc: 0.7633 - f1_m: 1.1383 - precision_m: 0.9346 - recall_m: 1.4585 - dice_coef: 1.0266
# Epoch 00076: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19790.2354 - acc: 0.7633 - f1_m: 1.1379 - precision_m: 0.9340 - recall_m: 1.4587 - dice_coef: 1.0266 - val_loss: 41622.8826 - val_acc: 0.7795 - val_f1_m: 0.9517 - val_precision_m: 0.7896 - val_recall_m: 1.1989 - val_dice_coef: 0.9891
# Epoch 77/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19680.8103 - acc: 0.7646 - f1_m: 1.1399 - precision_m: 0.9361 - recall_m: 1.4597 - dice_coef: 1.0270
# Epoch 00077: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19611.8027 - acc: 0.7646 - f1_m: 1.1400 - precision_m: 0.9353 - recall_m: 1.4622 - dice_coef: 1.0270 - val_loss: 42933.8560 - val_acc: 0.7671 - val_f1_m: 0.9582 - val_precision_m: 0.7752 - val_recall_m: 1.2565 - val_dice_coef: 0.9874
# Epoch 78/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19576.1950 - acc: 0.7644 - f1_m: 1.1406 - precision_m: 0.9368 - recall_m: 1.4603 - dice_coef: 1.0271
# Epoch 00078: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19537.7064 - acc: 0.7644 - f1_m: 1.1387 - precision_m: 0.9364 - recall_m: 1.4555 - dice_coef: 1.0270 - val_loss: 42608.9250 - val_acc: 0.7694 - val_f1_m: 0.9588 - val_precision_m: 0.7814 - val_recall_m: 1.2433 - val_dice_coef: 0.9880
# Epoch 79/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19631.3078 - acc: 0.7630 - f1_m: 1.1415 - precision_m: 0.9355 - recall_m: 1.4665 - dice_coef: 1.0271
# Epoch 00079: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19561.1809 - acc: 0.7630 - f1_m: 1.1418 - precision_m: 0.9346 - recall_m: 1.4701 - dice_coef: 1.0271 - val_loss: 42659.0428 - val_acc: 0.7678 - val_f1_m: 0.9581 - val_precision_m: 0.7790 - val_recall_m: 1.2463 - val_dice_coef: 0.9878
# Epoch 80/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19594.8648 - acc: 0.7638 - f1_m: 1.1403 - precision_m: 0.9366 - recall_m: 1.4596 - dice_coef: 1.0271
# Epoch 00080: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19535.6037 - acc: 0.7638 - f1_m: 1.1401 - precision_m: 0.9371 - recall_m: 1.4578 - dice_coef: 1.0272 - val_loss: 42896.2238 - val_acc: 0.7657 - val_f1_m: 0.9613 - val_precision_m: 0.7762 - val_recall_m: 1.2644 - val_dice_coef: 0.9876
# Epoch 81/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19599.5967 - acc: 0.7618 - f1_m: 1.1402 - precision_m: 0.9361 - recall_m: 1.4605 - dice_coef: 1.0271
# Epoch 00081: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19537.8674 - acc: 0.7617 - f1_m: 1.1402 - precision_m: 0.9362 - recall_m: 1.4604 - dice_coef: 1.0271 - val_loss: 42263.5154 - val_acc: 0.7755 - val_f1_m: 0.9570 - val_precision_m: 0.7835 - val_recall_m: 1.2320 - val_dice_coef: 0.9890
# Epoch 82/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19517.2191 - acc: 0.7628 - f1_m: 1.1419 - precision_m: 0.9354 - recall_m: 1.4677 - dice_coef: 1.0274
# Epoch 00082: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19458.4344 - acc: 0.7628 - f1_m: 1.1412 - precision_m: 0.9351 - recall_m: 1.4662 - dice_coef: 1.0273 - val_loss: 42289.9889 - val_acc: 0.7739 - val_f1_m: 0.9573 - val_precision_m: 0.7846 - val_recall_m: 1.2299 - val_dice_coef: 0.9888
# Epoch 83/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19466.4306 - acc: 0.7632 - f1_m: 1.1421 - precision_m: 0.9370 - recall_m: 1.4647 - dice_coef: 1.0274
# Epoch 00083: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19405.2049 - acc: 0.7632 - f1_m: 1.1416 - precision_m: 0.9371 - recall_m: 1.4630 - dice_coef: 1.0274 - val_loss: 42773.9759 - val_acc: 0.7683 - val_f1_m: 0.9583 - val_precision_m: 0.7819 - val_recall_m: 1.2397 - val_dice_coef: 0.9887
# Epoch 84/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19402.5332 - acc: 0.7629 - f1_m: 1.1435 - precision_m: 0.9367 - recall_m: 1.4700 - dice_coef: 1.0276
# Epoch 00084: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19341.7818 - acc: 0.7629 - f1_m: 1.1433 - precision_m: 0.9365 - recall_m: 1.4694 - dice_coef: 1.0276 - val_loss: 42882.0112 - val_acc: 0.7677 - val_f1_m: 0.9587 - val_precision_m: 0.7781 - val_recall_m: 1.2499 - val_dice_coef: 0.9886
# Epoch 85/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19261.5460 - acc: 0.7616 - f1_m: 1.1445 - precision_m: 0.9372 - recall_m: 1.4719 - dice_coef: 1.0279
# Epoch 00085: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19201.7990 - acc: 0.7616 - f1_m: 1.1443 - precision_m: 0.9371 - recall_m: 1.4717 - dice_coef: 1.0279 - val_loss: 43361.3842 - val_acc: 0.7649 - val_f1_m: 0.9607 - val_precision_m: 0.7766 - val_recall_m: 1.2610 - val_dice_coef: 0.9882
# Epoch 86/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19356.8541 - acc: 0.7620 - f1_m: 1.1440 - precision_m: 0.9364 - recall_m: 1.4726 - dice_coef: 1.0279
# Epoch 00086: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19291.6859 - acc: 0.7620 - f1_m: 1.1439 - precision_m: 0.9352 - recall_m: 1.4756 - dice_coef: 1.0278 - val_loss: 43210.2536 - val_acc: 0.7649 - val_f1_m: 0.9605 - val_precision_m: 0.7805 - val_recall_m: 1.2512 - val_dice_coef: 0.9883
# Epoch 87/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19196.6589 - acc: 0.7623 - f1_m: 1.1449 - precision_m: 0.9381 - recall_m: 1.4709 - dice_coef: 1.0280
# Epoch 00087: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19133.8388 - acc: 0.7623 - f1_m: 1.1449 - precision_m: 0.9380 - recall_m: 1.4711 - dice_coef: 1.0280 - val_loss: 43015.5894 - val_acc: 0.7708 - val_f1_m: 0.9586 - val_precision_m: 0.7816 - val_recall_m: 1.2411 - val_dice_coef: 0.9889
# Epoch 88/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19069.9740 - acc: 0.7604 - f1_m: 1.1476 - precision_m: 0.9376 - recall_m: 1.4804 - dice_coef: 1.0284
# Epoch 00088: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19023.6713 - acc: 0.7604 - f1_m: 1.1461 - precision_m: 0.9360 - recall_m: 1.4796 - dice_coef: 1.0283 - val_loss: 42748.6173 - val_acc: 0.7777 - val_f1_m: 0.9567 - val_precision_m: 0.7874 - val_recall_m: 1.2204 - val_dice_coef: 0.9897
# Epoch 89/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19031.6789 - acc: 0.7614 - f1_m: 1.1473 - precision_m: 0.9380 - recall_m: 1.4787 - dice_coef: 1.0286
# Epoch 00089: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18971.7953 - acc: 0.7615 - f1_m: 1.1470 - precision_m: 0.9373 - recall_m: 1.4793 - dice_coef: 1.0285 - val_loss: 42738.5187 - val_acc: 0.7763 - val_f1_m: 0.9564 - val_precision_m: 0.7856 - val_recall_m: 1.2239 - val_dice_coef: 0.9894
# Epoch 90/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19114.5732 - acc: 0.7624 - f1_m: 1.1458 - precision_m: 0.9376 - recall_m: 1.4753 - dice_coef: 1.0281
# Epoch 00090: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19071.9444 - acc: 0.7623 - f1_m: 1.1448 - precision_m: 0.9383 - recall_m: 1.4712 - dice_coef: 1.0282 - val_loss: 42644.8429 - val_acc: 0.7789 - val_f1_m: 0.9553 - val_precision_m: 0.7893 - val_recall_m: 1.2114 - val_dice_coef: 0.9894
# Epoch 91/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19044.7165 - acc: 0.7621 - f1_m: 1.1474 - precision_m: 0.9379 - recall_m: 1.4798 - dice_coef: 1.0284
# Epoch 00091: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18987.8482 - acc: 0.7622 - f1_m: 1.1467 - precision_m: 0.9375 - recall_m: 1.4783 - dice_coef: 1.0283 - val_loss: 42963.4687 - val_acc: 0.7717 - val_f1_m: 0.9596 - val_precision_m: 0.7833 - val_recall_m: 1.2400 - val_dice_coef: 0.9890
# Epoch 92/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19090.8187 - acc: 0.7615 - f1_m: 1.1468 - precision_m: 0.9378 - recall_m: 1.4782 - dice_coef: 1.0283
# Epoch 00092: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19040.3808 - acc: 0.7615 - f1_m: 1.1459 - precision_m: 0.9378 - recall_m: 1.4752 - dice_coef: 1.0283 - val_loss: 43221.6140 - val_acc: 0.7707 - val_f1_m: 0.9594 - val_precision_m: 0.7837 - val_recall_m: 1.2378 - val_dice_coef: 0.9891
# Epoch 93/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19081.9769 - acc: 0.7619 - f1_m: 1.1472 - precision_m: 0.9385 - recall_m: 1.4778 - dice_coef: 1.0285
# Epoch 00093: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 19016.2949 - acc: 0.7621 - f1_m: 1.1473 - precision_m: 0.9377 - recall_m: 1.4805 - dice_coef: 1.0284 - val_loss: 43436.2103 - val_acc: 0.7698 - val_f1_m: 0.9597 - val_precision_m: 0.7791 - val_recall_m: 1.2507 - val_dice_coef: 0.9887
# Epoch 94/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19008.8385 - acc: 0.7614 - f1_m: 1.1479 - precision_m: 0.9384 - recall_m: 1.4799 - dice_coef: 1.0285
# Epoch 00094: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18969.7276 - acc: 0.7614 - f1_m: 1.1461 - precision_m: 0.9373 - recall_m: 1.4767 - dice_coef: 1.0284 - val_loss: 43532.3212 - val_acc: 0.7682 - val_f1_m: 0.9585 - val_precision_m: 0.7796 - val_recall_m: 1.2466 - val_dice_coef: 0.9887
# Epoch 95/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 18967.2758 - acc: 0.7621 - f1_m: 1.1487 - precision_m: 0.9379 - recall_m: 1.4839 - dice_coef: 1.0286
# Epoch 00095: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18911.5134 - acc: 0.7620 - f1_m: 1.1480 - precision_m: 0.9376 - recall_m: 1.4824 - dice_coef: 1.0286 - val_loss: 42690.7836 - val_acc: 0.7748 - val_f1_m: 0.9567 - val_precision_m: 0.7859 - val_recall_m: 1.2244 - val_dice_coef: 0.9896
# Epoch 96/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 19047.2656 - acc: 0.7624 - f1_m: 1.1472 - precision_m: 0.9391 - recall_m: 1.4766 - dice_coef: 1.0287
# Epoch 00096: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18996.9438 - acc: 0.7626 - f1_m: 1.1451 - precision_m: 0.9356 - recall_m: 1.4811 - dice_coef: 1.0284 - val_loss: 43659.4108 - val_acc: 0.7721 - val_f1_m: 0.9607 - val_precision_m: 0.7810 - val_recall_m: 1.2498 - val_dice_coef: 0.9891
# Epoch 97/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 18825.4984 - acc: 0.7619 - f1_m: 1.1494 - precision_m: 0.9387 - recall_m: 1.4841 - dice_coef: 1.0287
# Epoch 00097: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18796.4175 - acc: 0.7619 - f1_m: 1.1476 - precision_m: 0.9392 - recall_m: 1.4783 - dice_coef: 1.0287 - val_loss: 44326.5754 - val_acc: 0.7701 - val_f1_m: 0.9614 - val_precision_m: 0.7785 - val_recall_m: 1.2589 - val_dice_coef: 0.9886
# Epoch 98/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 18800.0198 - acc: 0.7611 - f1_m: 1.1502 - precision_m: 0.9392 - recall_m: 1.4859 - dice_coef: 1.0289
# Epoch 00098: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18743.0757 - acc: 0.7610 - f1_m: 1.1498 - precision_m: 0.9393 - recall_m: 1.4844 - dice_coef: 1.0290 - val_loss: 44158.7964 - val_acc: 0.7700 - val_f1_m: 0.9608 - val_precision_m: 0.7797 - val_recall_m: 1.2552 - val_dice_coef: 0.9888
# Epoch 99/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 18779.6889 - acc: 0.7622 - f1_m: 1.1502 - precision_m: 0.9392 - recall_m: 1.4856 - dice_coef: 1.0290
# Epoch 00099: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18724.2186 - acc: 0.7622 - f1_m: 1.1498 - precision_m: 0.9394 - recall_m: 1.4839 - dice_coef: 1.0290 - val_loss: 43609.2891 - val_acc: 0.7737 - val_f1_m: 0.9587 - val_precision_m: 0.7823 - val_recall_m: 1.2395 - val_dice_coef: 0.9892
# Epoch 100/100
# 1024/1029 [============================>.] - ETA: 0s - loss: 18647.1032 - acc: 0.7607 - f1_m: 1.1511 - precision_m: 0.9399 - recall_m: 1.4867 - dice_coef: 1.0294
# Epoch 00100: val_loss did not improve from 40976.09843
# 1029/1029 [==============================] - 66s 64ms/sample - loss: 18588.7220 - acc: 0.7607 - f1_m: 1.1507 - precision_m: 0.9400 - recall_m: 1.4852 - dice_coef: 1.0294 - val_loss: 44893.9408 - val_acc: 0.7668 - val_f1_m: 0.9602 - val_precision_m: 0.7748 - val_recall_m: 1.2640 - val_dice_coef: 0.9882

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();
plt.savefig("loss.png")

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["f1_m"], label="f1_score")
plt.plot(results.history["val_f1_m"], label="val_f1_score")
plt.plot( np.argmin(results.history["val_f1_m"]), np.min(results.history["val_f1_m"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("f1_score")
plt.legend();
plt.savefig("f1.png")

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["acc"], label="accuracy")
plt.plot(results.history["val_acc"], label="val_accuracy")
plt.plot( np.argmin(results.history["val_acc"]), np.min(results.history["val_acc"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend();
plt.savefig("accuracy.png")

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["dice_coef"], label="dice_coef")
plt.plot(results.history["val_dice_coef"], label="val_dice_coef")
plt.plot( np.argmin(results.history["val_dice_coef"]), np.min(results.history["val_dice_coef"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("dice_coef")
plt.legend();
plt.savefig("dice_coef.png")

# %%
model.load_weights('model-deeplabvplus.h5')
loss, accuracy, f1_score, precision, recall , dice_score = model.evaluate(X_test, y_test, verbose=1)

print("loss:", loss)
print("Accuracy:", accuracy)
print("f1_score:", f1_score)
#print("unet_precision:", precision)
#print("unet_recall:", recall)
print("dice_score:", dice_score)
# Out:
# 686/686 [==============================] - 11s 15ms/sample - loss: 58730.0403 - acc: 0.8252 - f1_m: 0.9827 - precision_m: 0.8264 - recall_m: 1.2455 - dice_coef: 0.9937
# loss: 58730.04033231596
# Accuracy: 0.82518804
# f1_score: 0.98271567
# dice_score: 0.9936587
